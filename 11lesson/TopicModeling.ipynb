# %%
import os
import json
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
import re
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from openTSNE import TSNE
import umap
PATH = "./sample_data/"
# %matplotlib inline

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_json("./TopicModeling.json")

# %%
def preprocess_text(text, flag):
    text = text.lower()
    text = text.replace("abstract:","")
    text = re.sub("[^A-Za-z]+"," ",text)
    if flag:
        tokens = nltk.word_tokenize(text)
        tokens = [token for token in tokens if not token in stopwords.words("english")]
        text = " ".join(tokens)
    return text

# %%
df['cleaned_abstract'] = df['abstract'].apply(lambda x: preprocess_text(x,True))

# %%
df.head()
# Out:
#                                 url  \
# 0  https://arxiv.org/abs/2202.03622
# 1  https://arxiv.org/abs/2202.02773
# 2  https://arxiv.org/abs/2202.02429
# 3  https://arxiv.org/abs/2202.01203
# 4  https://arxiv.org/abs/2202.00791
#
#                                                title   date_publ  \
# 0  Title:The synergistic modulation of electronic...  8 Feb 2022
# 1  Title:Probing Cosmic Inflation with the LiteBI...  6 Feb 2022
# 2      Title:Verifying Inverse Model Neural Networks  4 Feb 2022
# 3  Title:High pressure induced precipitation in A...  2 Feb 2022
# 4   Title:Mars Terrain Segmentation with Less Labels  1 Feb 2022
#
#                                              authors  \
# 0  [Linfeng Yu, Jinyuan Xu, Chen Shen, E Zhou, Ji...
# 1  [LiteBIRD Collaboration: E. Allys, K. Arnold, ...
# 2  [Chelsea Sidrane, Sydney Katz, Anthony Corso, ...
# 3  [Abhinav Parakh, Andrew C. Lee, Stella Charito...
# 4             [Edwin Goh, Jingdao Chen, Brian Wilso]
#
#                                             abstract  \
# 0  Abstract:  The design of novel devices with sp...
# 1  Abstract:  LiteBIRD, the Lite (Light) satellit...
# 2  Abstract:  Inverse problems exist in a wide va...
# 3  Abstract:  Precipitate-matrix interactions gov...
# 4  Abstract:  Planetary rover systems need to per...
#
#                                           categories          url_pdf  \
# 0            [Materials Science (cond-mat.mtrl-sci)]  /pdf/2202.03622
# 1  [Instrumentation and Methods for Astrophysics ...  /pdf/2202.02773
# 2  [Machine Learning (cs.LG),  Logic in Computer ...  /pdf/2202.02429
# 3  [Materials Science (cond-mat.mtrl-sci),  Other...  /pdf/2202.01203
# 4  [Computer Vision and Pattern Recognition (cs.C...  /pdf/2202.00791
#
#                                     cleaned_abstract
# 0  design novel devices specific technical intere...
# 1  litebird lite light satellite study b mode pol...
# 2  inverse problems exist wide variety physical d...
# 3  precipitate matrix interactions govern mechani...
# 4  planetary rover systems need perform terrain s...

# %%
vecr = TfidfVectorizer(min_df=5, max_df=0.95)
X = vecr.fit_transform(df["cleaned_abstract"])

# %%
kmeans = KMeans(n_clusters=5,random_state=111)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=111)

# %% [markdown]
# ### TSNE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### UMAP

# %%
reducer = umap.UMAP(a=None, angular_rp_forest=False, b=None,
     force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
     local_connectivity=1.0, low_memory=False, metric='euclidean',
     metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
     n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
     output_metric_kwds=None, random_state=42, repulsion_strength=1.0,
     set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
     target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
     transform_queue_size=4.0, transform_seed=42, unique=False, verbose=False)

embedding = reducer.fit_transform(X)

# %%
df['y'] = embedding[:,0]
df['x'] = embedding[:,1]

# %%
df['cluster'] = clusters

# %%
clusters = kmeans.labels_

# %%
len(list(clusters))
# Out:
# 4317

# %%
df['cluster'] = clusters

# %%
df['y'] = svd_vec[:,0]
df['x'] = svd_vec[:,1]

# %%
def interpret(n):
    res = dict()
    centroids = pd.DataFrame(X.todense()).groupby(clusters).mean()
    terms = vecr.get_feature_names_out()
    for i,r in centroids.iterrows():
        res[i] = ",".join([terms[t] for t in np.argsort(r)[-n:]])
    return res

# %%
cluster_map = interpret(3)
df['cluster'] = df['cluster'].map(cluster_map)

# %%
df[["title","categories","cluster"]].head()
# Out:
#                                                title  \
# 0  Title:The synergistic modulation of electronic...
# 1  Title:Probing Cosmic Inflation with the LiteBI...
# 2      Title:Verifying Inverse Model Neural Networks
# 3  Title:High pressure induced precipitation in A...
# 4   Title:Mars Terrain Segmentation with Less Labels
#
#                                           categories               cluster
# 0            [Materials Science (cond-mat.mtrl-sci)]  space,system,control
# 1  [Instrumentation and Methods for Astrophysics ...  space,system,control
# 2  [Machine Learning (cs.LG),  Logic in Computer ...  space,system,control
# 3  [Materials Science (cond-mat.mtrl-sci),  Other...        solar,dust,ray
# 4  [Computer Vision and Pattern Recognition (cs.C...  space,system,control

# %% [markdown]
# ### Best result fot umap is with default params

# %%
plt.figure(figsize=(12,12))
plt.title("The first vizualization at the course")
sns.scatterplot(data=df,y='y',x='x', hue='cluster',palette='viridis');

# %%
df['date_publ'].unique().shape
# Out:
# (3417,)

# %%
df
# Out:
#                                    url  \
# 0     https://arxiv.org/abs/2202.03622
# 1     https://arxiv.org/abs/2202.02773
# 2     https://arxiv.org/abs/2202.02429
# 3     https://arxiv.org/abs/2202.01203
# 4     https://arxiv.org/abs/2202.00791
# ...                                ...
# 4312  https://arxiv.org/abs/2011.00110
# 4313  https://arxiv.org/abs/2010.15544
# 4314  https://arxiv.org/abs/2010.14185
# 4315  https://arxiv.org/abs/2010.13740
# 4316  https://arxiv.org/abs/2010.13524
#
#                                                   title  \
# 0     Title:The synergistic modulation of electronic...
# 1     Title:Probing Cosmic Inflation with the LiteBI...
# 2         Title:Verifying Inverse Model Neural Networks
# 3     Title:High pressure induced precipitation in A...
# 4      Title:Mars Terrain Segmentation with Less Labels
# ...                                                 ...
# 4312  Title:Extended-body motion in black hole space...
# 4313  Title:Algorithm for TDI numerical simulation a...
# 4314  Title:In-flight calibration system of Imaging ...
# 4315  Title:Possible Transient Luminous Events obser...
# 4316  Title:EPIC 216747137: a new HW Vir eclipsing b...
#
#                                               date_publ  \
# 0                                            8 Feb 2022
# 1                                            6 Feb 2022
# 2                                            4 Feb 2022
# 3                                            2 Feb 2022
# 4                                            1 Feb 2022
# ...                                                 ...
# 4312  30 Oct 2020 (v1), last revised 22 Dec 2020 (th...
# 4313  29 Oct 2020 (v1), last revised 3 Jun 2021 (thi...
# 4314                                        27 Oct 2020
# 4315                                        26 Oct 2020
# 4316                                        26 Oct 2020
#
#                                                 authors  \
# 0     [Linfeng Yu, Jinyuan Xu, Chen Shen, E Zhou, Ji...
# 1     [LiteBIRD Collaboration: E. Allys, K. Arnold, ...
# 2     [Chelsea Sidrane, Sydney Katz, Anthony Corso, ...
# 3     [Abhinav Parakh, Andrew C. Lee, Stella Charito...
# 4                [Edwin Goh, Jingdao Chen, Brian Wilso]
# ...                                                 ...
# 4312                                  [Abraham I. Hart]
# 4313  [Gang Wang, Wei-Tou Ni, Wen-Biao Han, Cong-Fen...
# 4314  [Riccardo Ferrazzoli, Fabio Muleri, Carlo Lefe...
# 4315  [Rohini S. Giles, Thomas K. Greathouse, Bertra...
# 4316  [R. Silvotti, V. Schaffenroth, U. Heber, R.H. ...
#
#                                                abstract  \
# 0     Abstract:  The design of novel devices with sp...
# 1     Abstract:  LiteBIRD, the Lite (Light) satellit...
# 2     Abstract:  Inverse problems exist in a wide va...
# 3     Abstract:  Precipitate-matrix interactions gov...
# 4     Abstract:  Planetary rover systems need to per...
# ...                                                 ...
# 4312  Abstract:  Free-fall is only approximately uni...
# 4313  Abstract:  We introduce a generic algorithm to...
# 4314  Abstract:  The NASA/ASI Imaging X-ray Polarime...
# 4315  Abstract:  11 transient bright flashes were de...
# 4316  Abstract:  EPIC 216747137 is a new HW~Virginis...
#
#                                              categories          url_pdf  \
# 0               [Materials Science (cond-mat.mtrl-sci)]  /pdf/2202.03622
# 1     [Instrumentation and Methods for Astrophysics ...  /pdf/2202.02773
# 2     [Machine Learning (cs.LG),  Logic in Computer ...  /pdf/2202.02429
# 3     [Materials Science (cond-mat.mtrl-sci),  Other...  /pdf/2202.01203
# 4     [Computer Vision and Pattern Recognition (cs.C...  /pdf/2202.00791
# ...                                                 ...              ...
# 4312  [General Relativity and Quantum Cosmology (gr-...  /pdf/2011.00110
# 4313  [General Relativity and Quantum Cosmology (gr-...  /pdf/2010.15544
# 4314  [Instrumentation and Methods for Astrophysics ...  /pdf/2010.14185
# 4315   [Earth and Planetary Astrophysics (astro-ph.EP)]  /pdf/2010.13740
# 4316     [Solar and Stellar Astrophysics (astro-ph.SR)]  /pdf/2010.13524
#
#                                        cleaned_abstract         y         x  \
# 0     design novel devices specific technical intere...  1.771306  1.956970
# 1     litebird lite light satellite study b mode pol...  4.595833  4.887866
# 2     inverse problems exist wide variety physical d...  0.288682  4.054230
# 3     precipitate matrix interactions govern mechani...  1.316708  2.429990
# 4     planetary rover systems need perform terrain s...  1.004237  3.286203
# ...                                                 ...       ...       ...
# 4312  free fall approximately universal general rela...  1.078156  5.759982
# 4313  introduce generic algorithm determine time del...  2.735208  3.047664
# 4314  nasa asi imaging x ray polarimetry explorer la...  5.011288  5.221002
# 4315  transient bright flashes detected jupiter atmo...  3.757681  7.822200
# 4316  epic new hw virginis system discovered kepler ...  4.803462  7.322281
#
#                                  cluster
# 0                   space,system,control
# 1                   space,system,control
# 2                   space,system,control
# 3                         solar,dust,ray
# 4                   space,system,control
# ...                                  ...
# 4312  acceleration,pioneer,gravitational
# 4313  acceleration,pioneer,gravitational
# 4314                      solar,dust,ray
# 4315                      solar,dust,ray
# 4316                      solar,dust,ray
#
# [4317 rows x 11 columns]

# %% [markdown]
# ### Lets group by month

# %%
data = df[["date_publ","x","y","cluster"]]
data["date_publ"] = data["date_publ"].apply(lambda x: " ".join(x.split()[1:-1]))
grouped = data.groupby("date_publ")
grouped.first()
# Out:
# C:\Users\1\AppData\Local\Temp/ipykernel_3192/2744421880.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["date_publ"] = data["date_publ"].apply(lambda x: " ".join(x.split()[1:-1]))
#                                                            x         y  \
# date_publ
# Apr                                                 1.968415  1.906438
# Apr 1999 (v1), last revised 13 Apr 1999 (this v...  1.108472  4.023982
# Apr 1999 (v1), last revised 3 Dec 2013 (this ve...  2.182722  3.389968
# Apr 2001 (v1), last revised 10 Mar 2005 (this v...  0.937936  3.949321
# Apr 2005 (v1), last revised 1 Jun 2006 (this ve...  0.946753  4.030168
# ...                                                      ...       ...
# Sep 2021 (v1), last revised 29 Sep 2021 (this v...  5.832633  8.220442
# Sep 2021 (v1), last revised 30 Nov 2021 (this v...  6.480432  9.231295
# Sep 2021 (v1), last revised 4 Jan 2022 (this ve...  5.870282  9.288371
# Sep 2021 (v1), last revised 8 Sep 2021 (this ve...  3.414153  0.077428
# Sep 2021 (v1), last revised 9 Dec 2021 (this ve...  5.742033  5.537422
#
#                                                                                cluster
# date_publ
# Apr                                                                     solar,dust,ray
# Apr 1999 (v1), last revised 13 Apr 1999 (this v...  acceleration,pioneer,gravitational
# Apr 1999 (v1), last revised 3 Dec 2013 (this ve...  acceleration,pioneer,gravitational
# Apr 2001 (v1), last revised 10 Mar 2005 (this v...  acceleration,pioneer,gravitational
# Apr 2005 (v1), last revised 1 Jun 2006 (this ve...  acceleration,pioneer,gravitational
# ...                                                                                ...
# Sep 2021 (v1), last revised 29 Sep 2021 (this v...                      solar,dust,ray
# Sep 2021 (v1), last revised 30 Nov 2021 (this v...                    coronal,cmes,cme
# Sep 2021 (v1), last revised 4 Jan 2022 (this ve...                    coronal,cmes,cme
# Sep 2021 (v1), last revised 8 Sep 2021 (this ve...                space,system,control
# Sep 2021 (v1), last revised 9 Dec 2021 (this ve...                      solar,dust,ray
#
# [1129 rows x 3 columns]

# %%
out = grouped.first().to_json(orient='records')
with open('group.json', 'w') as f:
    f.write(out)

# %% [markdown]
# ### Saving data

# %%
data = df[["date_publ","x","y","cluster"]]

out = data.to_json(orient='records')
with open('umap.json', 'w') as f:
    f.write(out)
